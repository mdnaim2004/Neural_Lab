# %% [markdown]
# ## Loop
#
# - two types of loop
#     1. while loop
#     2. for loop

# %% [markdown]
# ### While Loop

# %%
i = 1
while( i <= 5):
    print("iterate : ", i)
    i += 1
# Out:
# iterate :  1
# iterate :  2
# iterate :  3
# iterate :  4
# iterate :  5

# %% [markdown]
# ### For Loop
