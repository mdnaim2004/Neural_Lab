# %% [markdown]
# ## Defining Function

# %%
def greet():
    print("hello World!")

# %%
greet()
# Out:
# hello World!

# %%
def greet(name):
    print(f"hello hi {name}")

# %%
greet("naim")
# Out:
# hello hi naim

# %%
def func(name):
    print(f"hello {name}")

# %%
func("naim islam")
# Out:
# hello naim islam

# %%
def fun(name, age):
    print(f" hello {name}, your age is = {age}")

# %%
fun("naim", 22)
# Out:
#  hello naim, your age is = 22

# %% [markdown]
# ### Return values

# %%
def add(num1, num2):
    result = num1 + num2
    #return result
    print(f"result is = ",result)

add(50, 70)
# Out:
# result is =  120

# %%
add(5,9)
# Out:
# 14

# %%
add(60, 90)
# Out:
# 150

# %%
add_output = add(500, 700)
print(add_output)
# Out:
# result is =  1200
# None

# %%
def addd(num1, num2):
    result = num1 + num2
    print(result)

fun_output = addd(5000, 8000)
print(fun_output)
# Out:
# 13000
# None

# %%
def addd(num1, num2):
    result = num1 + num2
   

fun_output = addd(5000, 8000)
print(fun_output)
# Out:
# None

# %%
def odd_even(num):
    if num % 2 == 0:
        return "even"
    else:
        return "odd"
    

odd_even(69)
# Out:
# 'odd'

# %% [markdown]
# **tuple**

# %%
def odd_even(num):
    if num % 2 == 0:
        return "even",True
    else:
        return "odd", False
    

odd_even(69)
# Out:
# ('odd', False)

# %%
odd_even(50)
# Out:
# 'even'

# %%
s, b = odd_even(69)
# Out:
# 'odd'

# %%
s
# Out:
# 'odd'

# %%
b
# Out:
# False

# %%
tuple_var = (7,8,8)

# %%
x,y,z = tuple_var

# %%
x
# Out:
# 7

# %%
y
# Out:
# 8

# %%
z
# Out:
# 8
