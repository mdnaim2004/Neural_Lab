# %% [markdown]
# #### String methode.....

# %%
lable = " this is a text "
print(lable.upper());
# Out:
#  THIS IS A TEXT

# %%
lable = "   THIS IS A UPPER-CASE TEXT   "
print(lable.lower())
print(lable.title())
print(lable.strip())
print(lable.)
# Out:
#    this is a upper-case text
#    This Is A Upper-Case Text
# THIS IS A UPPER-CASE TEXT
