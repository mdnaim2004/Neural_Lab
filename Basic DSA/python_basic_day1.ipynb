# %% [markdown]
# ## String Methode.....
#
# - this is playing the game of string, and this is the string of the many concepts of this string,
# - in this string many times of operation,
# - this operation in opening to the (var_name.___)
# - this is  ____ meaning in this dash, many operation of execute in var_name.operation

# %%
lable = " this is a text "
print(lable.upper())
# Out:
#  THIS IS A TEXT

# %%
lable = "   THIS IS A UPPER-CASE TEXT   "
print(lable.lower())
print(lable.title())
print(lable.strip())
print(lable.capitalize())
print(lable.replace('A', 's'))
# Out:
#    this is a upper-case text
#    This Is A Upper-Case Text
# THIS IS A UPPER-CASE TEXT
#    this is a upper-case text
#    THIS IS s UPPER-CsSE TEXT

# %%
print(lable.replace('T', 's'))
# Out:
#    sHIS IS A UPPER-CASE sEXs

# %%
print(lable.strip().upper().title())
# Out:
# This Is A Upper-Case Text

# %% [markdown]
# ## Number & Math Operations

# %% [markdown]
# - in this operation is mathmatical operation...
# -   '+'
# -   '-'
# -   '*'
# -   /
# -   //
# -   %
# -   **

# %% [markdown]
# ### in python follow the order
# - parentheses ()
# - Exponents **
# - (*, /, //, %)
# - (+, -)
# - Comparisons
# - Logical Operator

# %%
a = 10
b = 5
c = 2

eq = (a*b)/(a+b) + (a**c) - (a//c)

# 50/15+100-5
# 3.33+100-5
# 3.33+95
# 98.33

print("the result is = ",eq)

z = (a*b)  # 10*5 = 50

print(z)
# Out:
# the result is =  98.33333333333333
# 50

# %%
y = z/(a+b) 
print(y)
# Out:
# 3.3333333333333335

# %%
m = (a**c)
print(m)

n = (a//c)
print(n)
# Out:
# 100
# 5

# %% [markdown]
# ## Math Functions
#
# - new liberaryor math functions....
# - in this function to import math function, then we will call math.   then all mathmaticiall function are avaliavble....
#
# ---
# there is a many operation in the case of 'import math' liberary import, the it use what we need
#
# ---

# %%
import math

print(math.sqrt(4))
print(math.ceil(5.43))
print(math.floor(5.46))
print(math.pi)
# Out:
# 2.0
# 6
# 5
# 3.141592653589793

# %% [markdown]
# ## Conditional Statement
#
# ---
# conditional statement is make a condition to sure that if any work done or not
#
# ---
#
# ### Syntax
# ---
# ```
# if condition:
#
#     operation
#
# else:
#
#     operation
# ```
# ---

# %%
num = 40

num += 1

if num > 40:
    print("Passed")
else:
    print("failed")
# Out:
# Pass

# %%
num += 1

if num > 40:
    print("Passed")
else:
    print("failed")
# Out:
# Passed

# %% [markdown]
# ### pass mark condition

# %%
num = 40

if num > 80:
    print("Latter mark!")
elif num > 40:
    print("Passed")
else:
    print("failed")
# Out:
# failed

# %%
num = 82

if num > 80:
    print("Latter mark!")
elif num > 40:
    print("Passed")
else:
    print("failed")
# Out:
# Latter mark!

# %%
num = 70

if num > 80:
    print("Latter mark!")
elif num > 40:
    print("Passed")
else:
    print("failed")
# Out:
# Passed

# %% [markdown]
# ## Logical Operator
#
# - operator -------------------------------description
#
# ---
# - and    -------------------------------=  True if both are true
# - or     -------------------------------=  True if at least one true
# - not    -------------------------------=  Reverse True or False
# ---

# %% [markdown]
# #### and operation
#
# - and operation is a operation that both condition are fullfill then it execute otherwise it not working

# %%
age = 30

salary = 1000

if age > 25 and salary < 1000:
    print(" Straggling")
else:
    print("Missed any one Condition")
# Out:
# Missed any one Condition

# %%
age = 30

salary = 999

if age > 25 and salary < 1000:
    print(" Straggling")
else:
    print("Missed any one Condition")
# Out:
#  Straggling

# %% [markdown]
# ### or operation
#
# - or operation is a operation that if one condition is execute, it will work.....

# %%
age = 30

salary = 1001

if age > 25 or salary < 1000:
    print(" Straggling")
else:
    print("Missed any one Condition")
# Out:
#  Straggling

# %%
age = 20

salary = 1001

if age > 25 and salary < 100:
    print(" Straggling")
else:
    print("Missed any one Condition")
# Out:
# Missed any one Condition

# %% [markdown]
# #### bool datatype
# - it make true or false,

# %%
is_working = False
print(is_working)
# Out:
# False

# %% [markdown]
# #### not keyword
# - not keyword is reversely work, if condition is ture it can reverse false,and it false, then it convert false

# %%
print(not is_working)
# Out:
# True

# %% [markdown]
# ### Comparison Operator.
#
# - operator-----------Meaning
# - == --------------- equal to
# - != ---------------Not Equal
# - < ---------------- lessthan
# - '>'---------------- greaterthan
# - '>=' ------------- greater or equal
# - < ---------------- less or equal

# %% [markdown]
# ---
#
# - variable asign alwyas =
# - comparisn operator ==
# ---

# %%
age = 30
age == 30
# Out:
# True

# %%
age == 31
# Out:
# False

# %%
# value assign
age = 22
print(age == 22) # comparisn operator (equal equal)
print(age != 22) # Not equal
print(age > 30)
print(age < 30)
# Out:
# True
# False
# False
# True

# %%
print(age <= 25)
print(age >= 21)
# Out:
# True
# True

# %%
print(age <= 20)
print(age >= 25)
# Out:
# False
# False

# %% [markdown]
# # Loop

# %% [markdown]
# ## While Loop
#
# - while loop runs the based on a condition

# %%
# while condition:
        # operation

# %%
cnt = 1

while(cnt <= 5):
    print("count : ", cnt)
    cnt += 1              # cnt = cnt+1
    print("Update count value : ", cnt, "\n")
# Out:
# count :  1
# Update count value :  2
#
# count :  2
# Update count value :  3
#
# count :  3
# Update count value :  4
#
# count :  4
# Update count value :  5
#
# count :  5
# Update count value :  6

# %% [markdown]
# in this day im learnint this some topic
# - one eyes of revew of topic
#
# 1. String methode
# 2. Number of Math Operation
# 3. Math Function
# 4. Conditional Statement
# 5. Logical Operator
# 6. Comparisn Operator
# 7. Loop
#     - while loop
