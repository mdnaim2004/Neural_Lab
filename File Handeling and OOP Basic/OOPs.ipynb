# %% [markdown]
# ## Introduction to OOPs (Object Orentade Programing system)

# %% [markdown]
# #### OOPs is a programing paradigm based based on:
# - Classes -- blueprint
# - Objects -- instances
# - Attributes -- variable inside a class
# - Methodes -- function inside a class
#
# #### Main OOP principles:
# - **Encaptulation** : Keeping data and methos together in a class and restracting direc access to internal data.
# - **Inheritance** : One class drives from another, gainig its properties and behaviour(code reuse)
# - **Polymorphism** : Same methode name behaving differently depending on the object calling it.
# - **Abstrution** : Showing only essential feature while hiding unnecessary implemention details.

# %% [markdown]
# ### Class and Objects

# %% [markdown]
# class is a realworld entity,<br>
# it is a blue print or template<br>propertis of the class,<br>methods is function of the class, on this methode, task of the multiple task of the class,
#
# <br>
# <b>encaptulation</b> in this encaptulation make sure of the data<br>propertis of the inherit of the others object, or parent into child of inherit<br>
# <b>polymorphysm</b> it means

# %% [markdown]
# <b>syntax</b><br>
# class class_name:<br>

# %%
class person:
    pass

# %%
p1 = person()
print(p1)

# %% [markdown]
# ## Attribute and Methode

# %%
class car:
    def __init__(self, brand, color):
        self.brand = brand
        self.color = color
    

my_car = car("BMW", "Black")

print(my_car.brand)
print(my_car.color)
# Out:
# BMW
# Black

# %% [markdown]
# #### Methode

# %%
class car:
    def __init__(self, brand, color):
        self.brand = brand
        self.color = color

    def drive(self):
        print(f"The {self.brand} is driving")

car1 = car("BMW", "Black")
car1.drive()
# Out:
# The BMW is driving

# %%
class Student:
    def __init__(self, name, id, gender, sub, dept):
        self.name = name
        self.id = id
        self.gender = gender
        self.sub = sub
        self.dept = dept

    def study(self):
        print(f"{self.name} is studying {self.sub}")

    def info(self):
        print(f"Name : {self.name} \n ID : {self.id} \n Gender : {self.gender} \n SUB : {self.sub} \n Dept : {self.dept}")

# %%
student1 = Student("Naim", 68, "Male", "CSE", "S&E")

# %%
student1.study()
# Out:
# Naim is studying CSE

# %%
student1.info()
# Out:
# Name : Naim
#  ID : 68
#  Gender : Male
#  SUB : CSE
#  Dept : S&E

# %%
def func(para1, para2):
    print(para1, para2)

func("Hello", 1234)
# Out:
# Hello 1234

# %%
class Studentss:
    def __init__(self, i, g, s):
        self.name = None
        self.id = i
        self.gender = g
        self.subject = s

    def study(self):
        print(f"{self.name} is studying {self.subject}")

    def info(self):
        print(f"Name = {self.name}\n {self.id} \n {self.gender} \n {self.subject}")

student2 = Studentss("1", "male", "CSE")
print(student2.info())
# Out:
# Name = None
#  1
#  male
#  CSE
# None

# %% [markdown]
# ## Mini Project : Student Grade Calculator

# %%
class Stud:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    def grade_calculate(self):
        if self.marks >= 90:
            return "A"
        elif self.marks >= 80:
            return "B"
        elif self.marks >= 60:
            return "C"
        else:
            return "F"


# main file....
name = input("Enter your name : ")
marks = int(input("Enter your marks : "))   # FIXED

std = Stud(name, marks)
grd = std.grade_calculate()

print(f"Student : {std.name}, Grade : {grd}")   # FIXED

# save to file...
with open("grade.txt", "a") as f:
    f.write(f"{std.name} - {grd}\n")   # FIXED

print("Data saved to grade.txt")
# Out:
# Student : Mdnaim, Grade : B
# Data saved to grade.txt
