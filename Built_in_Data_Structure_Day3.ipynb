# %% [markdown]
# ## Tuple
#
# A tuple is an ordered immutable collection in python. tuples are writen with parenthease().
#
# tuple characterastrics:
#
# - Orderd --> element have a define orderd
# - immutable --> cannot change element after creation.
# - cannot duplicate
# - can contain diffrent data type

# %%
# tuple define

tpl = (1, 2, 3)
print(type (tpl))

a_list = [10, 20, 30, 40,50,40, 70, 60, 50, 60, 70, 80, 90,50,50, 50]
print(type(a_list))

# type cast

a_tuple = tuple(a_list)
print(type(a_tuple))
print(a_tuple)
# Out:
# <class 'tuple'>
# <class 'list'>
# <class 'tuple'>
# (10, 20, 30, 40, 50, 40, 70, 60, 50, 60, 70, 80, 90, 50, 50, 50)

# %% [markdown]
# ## Tuple Methode
# - methode --------------Descriptions
# - count(x)--------------return the number of x appars in the tuple
# - index(x)--------------returns the index of the first occurrence of x.

# %%
a_tuple.count(50)
# Out:
# 5

# %%
a_tuple.index
# Out:
# <function tuple.index(value, start=0, stop=9223372036854775807, /)>

# %%
b_tuple = ('a', 'b', 'c', 'd')
c_tuple = a_tuple + b_tuple

print(c_tuple)
# Out:
# (10, 20, 30, 40, 50, 40, 70, 60, 50, 60, 70, 80, 90, 50, 50, 50, 'a', 'b', 'c', 'd')

# %% [markdown]
# ## Set
#
# A set is an unorderd, mutable collection of unique elements.
#
# Sets are writen with culy braces{} or set().
#
# Set Charactristric
# - Unorderd --> no indixcing
# - Mutable -->can add/remove elements.
# - No duplicates
# - can performs mathmetical set operations

# %% [markdown]
# [], (), {}

# %%
set_a = {1, 2, 3}
set_b = {2,3,4}

set_a + set_b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 set_a = {1, 2, 3}
#       2 set_b = {2,3,4}
# ----> 4 set_a + set_b
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'
